# %% [markdown]
# # Projeto Python IA: Inteligência Artificial e Previsões
#
# ### Case: Score de Crédito dos Clientes
#
# Você foi contratado por um banco para conseguir definir o score de crédito dos clientes. Você precisa analisar todos os clientes do banco e, com base nessa análise, criar um modelo que consiga ler as informações do cliente e dizer automaticamente o score de crédito dele: Ruim, Ok, Bom
#
# Arquivos da aula: https://drive.google.com/drive/folders/1FbDqVq4XLvU85VBlVIMJ73p9oOu6u2-J?usp=drive_link

# %%
# Analisando 1 cliente
# Se o cliente é bom, ok ou ruim (Nota de crédito dele = Score de crédito)

# Passo a passo:
# Passo 0: Entender o desafio da empresa
# Passo 1: Importar base de dados

import pandas as pd
import sklearn

tabela = pd.read_csv("clientes.csv")

display(tabela)

# %%
# Passo 2: Tratar e preparar a base de dados para a inteligência artificial

from sklearn.preprocessing import LabelEncoder

# Profissão
codificador_profissao = LabelEncoder()
tabela["profissao"] = codificador_profissao.fit_transform(tabela["profissao"])

# Mix de Crédito
codificador_mix = LabelEncoder()
tabela["mix_credito"] = codificador_mix.fit_transform(tabela["mix_credito"])

# Comportamento Pagamento
codificador_comportamento = LabelEncoder()
tabela["comportamento_pagamento"] = codificador_comportamento.fit_transform(tabela["comportamento_pagamento"])

display(tabela)

# %%
# y é quem eu vou prever
y = tabela["score_credito"]

# x é quem eu vou usar pra fazer a previsão
x = tabela.drop(columns=["score_credito", "id_cliente"])

from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3)

# %%
# Passo 3: Criar o  modelo de previsão ou modelo de IA -> Ruim, OK, Boa

# º Passo 1 : Importar a IA (Modelo)
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# º Passo 2: Criar a IA (Modelo)
modelo_arvoredecisao = RandomForestClassifier()
modelo_knn = KNeighborsClassifier()

# º Passo 3: Treinar a IA (Modelo)
modelo_arvoredecisao.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)

# %%
# Passo 4: Avaliar e escolher o melhor modelo

previsao_arvore = modelo_arvoredecisao.predict(x_teste)
previsao_knn = modelo_knn.predict(x_teste)

from sklearn.metrics import accuracy_score

print("Arvore de decisões:", accuracy_score(y_teste, previsao_arvore))
print("KNN:", accuracy_score(y_teste, previsao_knn))

# %%
# Passo 5: Fazer novas previsões

# Melhor modelo = Árvore de Decisões

# Importar os novos clientes

tabela_novos_clientes = pd.read_csv("novos_clientes.csv")

tabela_novos_clientes["profissao"] = codificador_profissao.transform(tabela_novos_clientes["profissao"])
tabela_novos_clientes["mix_credito"] = codificador_mix.transform(tabela_novos_clientes["mix_credito"])
tabela_novos_clientes["comportamento_pagamento"] = codificador_comportamento.transform(tabela_novos_clientes["comportamento_pagamento"])

previsao = modelo_arvoredecisao.predict(tabela_novos_clientes)

display(previsao)

display(tabela_novos_clientes)
